# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Veri dosyasının yolu
file_path = r"C:\Users\halha\Downloads\Turnstile_Usage_Data__2022_20240124.csv"

# Veriyi oku
df1 = pd.read_csv(file_path)

# Veriyi yazdır
print(df1)
# Out:
#             C/A  Unit       SCP        Station Line Name Division        Date  \
# 0          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# 1          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# 2          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# 3          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# 4          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# ...         ...   ...       ...            ...       ...      ...         ...
# 10963246  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
# 10963247  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
# 10963248  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
# 10963249  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
# 10963250  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
#
# ...

# %%
from IPython.display import display

pd.options.display.max_columns = None
display(df1)
# Out:
#             C/A  Unit       SCP        Station Line Name Division        Date  \
# 0          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# 1          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# 2          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# 3          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# 4          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# ...         ...   ...       ...            ...       ...      ...         ...
# 10963246  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
# 10963247  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
# 10963248  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
# 10963249  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
# 10963250  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
#
# ...

# %%
df1.columns
# Out:
# Index(['C/A', 'Unit', 'SCP', 'Station', 'Line Name', 'Division', 'Date',
#        'Time', 'Description', 'Entries',
#        'Exits                                                     '],
#       dtype='object')

# %%
df1.isnull().sum()
# Out:
# C/A                                                           0
# Unit                                                          0
# SCP                                                           0
# Station                                                       0
# Line Name                                                     0
# Division                                                      0
# Date                                                          0
# Time                                                          0
# Description                                                   0
# Entries                                                       0
# Exits                                                         0
# dtype: int64

# %%
df1.info
# Out:
# <bound method DataFrame.info of             C/A  Unit       SCP        Station Line Name Division        Date  \
# 0          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# 1          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# 2          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# 3          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# 4          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# ...         ...   ...       ...            ...       ...      ...         ...
# 10963246  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
# 10963247  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
# 10963248  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
# 10963249  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
# 10963250  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
#
# ...

# %%
df1.head(25)
# Out:
#      C/A  Unit       SCP Station Line Name Division        Date      Time  \
# 0   A002  R051  02-00-00   59 ST   NQR456W      BMT  12/30/2022  03:00:00
# 1   A002  R051  02-00-00   59 ST   NQR456W      BMT  12/30/2022  07:00:00
# 2   A002  R051  02-00-00   59 ST   NQR456W      BMT  12/30/2022  11:00:00
# 3   A002  R051  02-00-00   59 ST   NQR456W      BMT  12/30/2022  15:00:00
# 4   A002  R051  02-00-00   59 ST   NQR456W      BMT  12/30/2022  19:00:00
# 5   A002  R051  02-00-00   59 ST   NQR456W      BMT  12/30/2022  23:00:00
# 6   A002  R051  02-00-01   59 ST   NQR456W      BMT  12/30/2022  03:00:00
# 7   A002  R051  02-00-01   59 ST   NQR456W      BMT  12/30/2022  07:00:00
# 8   A002  R051  02-00-01   59 ST   NQR456W      BMT  12/30/2022  11:00:00
# 9   A002  R051  02-00-01   59 ST   NQR456W      BMT  12/30/2022  15:00:00
# 10  A002  R051  02-00-01   59 ST   NQR456W      BMT  12/30/2022  19:00:00
# 11  A002  R051  02-00-01   59 ST   NQR456W      BMT  12/30/2022  23:00:00
# ...

# %%
file_path = r"C:\Users\halha\OneDrive\Masaüstü\archive\NYC_Weather_2016_2022.csv"

df2 = pd.read_csv(file_path)
print(df2)
# Out:
#                       Date  temperature_2m (°C)  precipitation (mm)  \
# 0      2016-01-01 00:00:00                  7.6                 0.0
# 1      2016-01-01 01:00:00                  7.5                 0.0
# 2      2016-01-01 02:00:00                  7.1                 0.0
# 3      2016-01-01 03:00:00                  6.6                 0.0
# 4      2016-01-01 04:00:00                  6.3                 0.0
# ...                    ...                  ...                 ...
# 59582  2022-10-19 19:00:00                 12.2                 0.0
# 59583  2022-10-19 20:00:00                 12.2                 0.0
# 59584  2022-10-19 21:00:00                 12.2                 0.0
# 59585  2022-10-19 22:00:00                 11.1                 0.0
# 59586  2022-10-19 23:00:00                 10.4                 0.0
#
#        rain (mm)  cloudcover (%)  cloudcover_low (%)  cloudcover_mid (%)  \
# 0            0.0            69.0                53.0                 0.0
# ...

# %%
from IPython.display import display

pd.options.display.max_columns = None
display(df2)
# Out:
#                       Date  temperature_2m (°C)  precipitation (mm)  \
# 0      2016-01-01 00:00:00                  7.6                 0.0
# 1      2016-01-01 01:00:00                  7.5                 0.0
# 2      2016-01-01 02:00:00                  7.1                 0.0
# 3      2016-01-01 03:00:00                  6.6                 0.0
# 4      2016-01-01 04:00:00                  6.3                 0.0
# ...                    ...                  ...                 ...
# 59582  2022-10-19 19:00:00                 12.2                 0.0
# 59583  2022-10-19 20:00:00                 12.2                 0.0
# 59584  2022-10-19 21:00:00                 12.2                 0.0
# 59585  2022-10-19 22:00:00                 11.1                 0.0
# 59586  2022-10-19 23:00:00                 10.4                 0.0
#
#        rain (mm)  cloudcover (%)  cloudcover_low (%)  cloudcover_mid (%)  \
# 0            0.0            69.0                53.0                 0.0
# ...

# %%
df2.isnull().sum()
# Out:
# Date                     0
# temperature_2m (°C)      0
# precipitation (mm)       0
# rain (mm)                0
# cloudcover (%)           0
# cloudcover_low (%)       0
# cloudcover_mid (%)       0
# cloudcover_high (%)      0
# windspeed_10m (km/h)     0
# winddirection_10m (°)    0
# dtype: int64

# %%
# 'time' sütununun adını 'Time' olarak değiştir
df2 = df2.rename(columns={'Time': 'Date'})




# Değiştirilmiş DataFrame'i ekrana yazdır
print(df2.head())
# Out:
#                   Date  temperature_2m (°C)  precipitation (mm)  rain (mm)  \
# 0  2016-01-01 00:00:00                  7.6                 0.0        0.0
# 1  2016-01-01 01:00:00                  7.5                 0.0        0.0
# 2  2016-01-01 02:00:00                  7.1                 0.0        0.0
# 3  2016-01-01 03:00:00                  6.6                 0.0        0.0
# 4  2016-01-01 04:00:00                  6.3                 0.0        0.0
#
#    cloudcover (%)  cloudcover_low (%)  cloudcover_mid (%)  \
# 0            69.0                53.0                 0.0
# 1            20.0                 4.0                 0.0
# 2            32.0                 3.0                 0.0
# 3            35.0                 5.0                 0.0
# 4            34.0                 4.0                 0.0
#
#    cloudcover_high (%)  windspeed_10m (km/h)  winddirection_10m (°)
# 0                 72.0                  10.0                  296.0
# ...

# %%
df2.to_csv('C:\\Users\\halha\\OneDrive\\Masaüstü\\archive\\NYC_Weather_2016_2022.csv', index=False)

# %%
from IPython.display import display

pd.options.display.max_columns = None
display(df2)
# Out:
#                       Date  temperature_2m (°C)  precipitation (mm)  \
# 0      2016-01-01 00:00:00                  7.6                 0.0
# 1      2016-01-01 01:00:00                  7.5                 0.0
# 2      2016-01-01 02:00:00                  7.1                 0.0
# 3      2016-01-01 03:00:00                  6.6                 0.0
# 4      2016-01-01 04:00:00                  6.3                 0.0
# ...                    ...                  ...                 ...
# 59582  2022-10-19 19:00:00                 12.2                 0.0
# 59583  2022-10-19 20:00:00                 12.2                 0.0
# 59584  2022-10-19 21:00:00                 12.2                 0.0
# 59585  2022-10-19 22:00:00                 11.1                 0.0
# 59586  2022-10-19 23:00:00                 10.4                 0.0
#
#        rain (mm)  cloudcover (%)  cloudcover_low (%)  cloudcover_mid (%)  \
# 0            0.0            69.0                53.0                 0.0
# ...

# %%
# 'Date' sütununu datetime türüne dönüştür
df2['Date'] = pd.to_datetime(df2['Date'])

# 'Date' sütunundan sadece tarih kısmını seçin
df2['Date'] = df2['Date'].dt.date

# Güncellenmiş DataFrame'i ekrana yazdır
print(df2)
# Out:
#              Date  temperature_2m (°C)  precipitation (mm)  rain (mm)  \
# 0      2016-01-01                  7.6                 0.0        0.0
# 1      2016-01-01                  7.5                 0.0        0.0
# 2      2016-01-01                  7.1                 0.0        0.0
# 3      2016-01-01                  6.6                 0.0        0.0
# 4      2016-01-01                  6.3                 0.0        0.0
# ...           ...                  ...                 ...        ...
# 59582  2022-10-19                 12.2                 0.0        0.0
# 59583  2022-10-19                 12.2                 0.0        0.0
# 59584  2022-10-19                 12.2                 0.0        0.0
# 59585  2022-10-19                 11.1                 0.0        0.0
# 59586  2022-10-19                 10.4                 0.0        0.0
#
#        cloudcover (%)  cloudcover_low (%)  cloudcover_mid (%)  \
# 0                69.0                53.0                 0.0
# ...

# %%
from IPython.display import display

pd.options.display.max_columns = None
display(df2)
# Out:
#              Date  temperature_2m (°C)  precipitation (mm)  rain (mm)  \
# 0      2016-01-01                  7.6                 0.0        0.0
# 1      2016-01-01                  7.5                 0.0        0.0
# 2      2016-01-01                  7.1                 0.0        0.0
# 3      2016-01-01                  6.6                 0.0        0.0
# 4      2016-01-01                  6.3                 0.0        0.0
# ...           ...                  ...                 ...        ...
# 59582  2022-10-19                 12.2                 0.0        0.0
# 59583  2022-10-19                 12.2                 0.0        0.0
# 59584  2022-10-19                 12.2                 0.0        0.0
# 59585  2022-10-19                 11.1                 0.0        0.0
# 59586  2022-10-19                 10.4                 0.0        0.0
#
#        cloudcover (%)  cloudcover_low (%)  cloudcover_mid (%)  \
# 0                69.0                53.0                 0.0
# ...

# %%
# 'Date' sütununu datetime türüne dönüştür
df2['Date'] = pd.to_datetime(df2['Date'])

# 'Date' sütunundaki tarih formatını değiştir
df2['Date'] = df2['Date'].dt.strftime('%d-%m-%Y')

# Güncellenmiş DataFrame'i ekrana yazdır
print(df2)
# Out:
#              Date  temperature_2m (°C)  precipitation (mm)  rain (mm)  \
# 0      01-01-2016                  7.6                 0.0        0.0
# 1      01-01-2016                  7.5                 0.0        0.0
# 2      01-01-2016                  7.1                 0.0        0.0
# 3      01-01-2016                  6.6                 0.0        0.0
# 4      01-01-2016                  6.3                 0.0        0.0
# ...           ...                  ...                 ...        ...
# 59582  19-10-2022                 12.2                 0.0        0.0
# 59583  19-10-2022                 12.2                 0.0        0.0
# 59584  19-10-2022                 12.2                 0.0        0.0
# 59585  19-10-2022                 11.1                 0.0        0.0
# 59586  19-10-2022                 10.4                 0.0        0.0
#
#        cloudcover (%)  cloudcover_low (%)  cloudcover_mid (%)  \
# 0                69.0                53.0                 0.0
# ...

# %%
from IPython.display import display

pd.options.display.max_columns = None
display(df2)
# Out:
#              Date  temperature_2m (°C)  precipitation (mm)  rain (mm)  \
# 0      01-01-2016                  7.6                 0.0        0.0
# 1      01-01-2016                  7.5                 0.0        0.0
# 2      01-01-2016                  7.1                 0.0        0.0
# 3      01-01-2016                  6.6                 0.0        0.0
# 4      01-01-2016                  6.3                 0.0        0.0
# ...           ...                  ...                 ...        ...
# 59582  19-10-2022                 12.2                 0.0        0.0
# 59583  19-10-2022                 12.2                 0.0        0.0
# 59584  19-10-2022                 12.2                 0.0        0.0
# 59585  19-10-2022                 11.1                 0.0        0.0
# 59586  19-10-2022                 10.4                 0.0        0.0
#
#        cloudcover (%)  cloudcover_low (%)  cloudcover_mid (%)  \
# 0                69.0                53.0                 0.0
# ...

# %%
df2.columns
# Out:
# Index(['Date', 'temperature_2m (°C)', 'precipitation (mm)', 'rain (mm)',
#        'cloudcover (%)', 'cloudcover_low (%)', 'cloudcover_mid (%)',
#        'cloudcover_high (%)', 'windspeed_10m (km/h)', 'winddirection_10m (°)'],
#       dtype='object')

# %%
df2
# Out:
#              Date  temperature_2m (°C)  precipitation (mm)  rain (mm)  \
# 0      01-01-2016                  7.6                 0.0        0.0
# 1      01-01-2016                  7.5                 0.0        0.0
# 2      01-01-2016                  7.1                 0.0        0.0
# 3      01-01-2016                  6.6                 0.0        0.0
# 4      01-01-2016                  6.3                 0.0        0.0
# ...           ...                  ...                 ...        ...
# 59582  19-10-2022                 12.2                 0.0        0.0
# 59583  19-10-2022                 12.2                 0.0        0.0
# 59584  19-10-2022                 12.2                 0.0        0.0
# 59585  19-10-2022                 11.1                 0.0        0.0
# 59586  19-10-2022                 10.4                 0.0        0.0
#
#        cloudcover (%)  cloudcover_low (%)  cloudcover_mid (%)  \
# 0                69.0                53.0                 0.0
# ...

# %%
# 'Date' sütununu datetime türüne dönüştür
df2['Date'] = pd.to_datetime(df2['Date'])

# 'Date' sütunundaki tarih formatını değiştir
df2['Date'] = df2['Date'].dt.strftime('%d-%m-%Y')

# Güncellenmiş DataFrame'i ekrana yazdır
print(df2)
# Out:
# C:\Users\halha\AppData\Local\Temp\ipykernel_1736\2538587919.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df2['Date'] = pd.to_datetime(df2['Date'])
#              Date  temperature_2m (°C)  precipitation (mm)  rain (mm)  \
# 0      01-01-2016                  7.6                 0.0        0.0
# 1      01-01-2016                  7.5                 0.0        0.0
# 2      01-01-2016                  7.1                 0.0        0.0
# 3      01-01-2016                  6.6                 0.0        0.0
# 4      01-01-2016                  6.3                 0.0        0.0
# ...           ...                  ...                 ...        ...
# 59582  19-10-2022                 12.2                 0.0        0.0
# 59583  19-10-2022                 12.2                 0.0        0.0
# ...

# %%
from IPython.display import display

pd.options.display.max_columns = None
display(df2)
# Out:
#              Date  temperature_2m (°C)  precipitation (mm)  rain (mm)  \
# 0      01-01-2016                  7.6                 0.0        0.0
# 1      01-01-2016                  7.5                 0.0        0.0
# 2      01-01-2016                  7.1                 0.0        0.0
# 3      01-01-2016                  6.6                 0.0        0.0
# 4      01-01-2016                  6.3                 0.0        0.0
# ...           ...                  ...                 ...        ...
# 59582  19-10-2022                 12.2                 0.0        0.0
# 59583  19-10-2022                 12.2                 0.0        0.0
# 59584  19-10-2022                 12.2                 0.0        0.0
# 59585  19-10-2022                 11.1                 0.0        0.0
# 59586  19-10-2022                 10.4                 0.0        0.0
#
#        cloudcover (%)  cloudcover_low (%)  cloudcover_mid (%)  \
# 0                69.0                53.0                 0.0
# ...

# %%
# İki veri setini 'Date' sütununa göre birleştir
df = pd.merge(df1, df2, on='Date', how='inner')

# Birleştirilmiş DataFrame'i ekrana yazdır
print(df)
# Out:
# Empty DataFrame
# Columns: [C/A, Unit, SCP, Station, Line Name, Division, Date, Time, Description, Entries, Exits                                                     , temperature_2m (°C), precipitation (mm), rain (mm), cloudcover (%), cloudcover_low (%), cloudcover_mid (%), cloudcover_high (%), windspeed_10m (km/h), winddirection_10m (°)]
# Index: []

# %%
# Tarih aralığını belirle
start_date = '2022-03-15'
end_date = '2022-06-01'

# Belirli tarih aralığındaki verileri seç
df1_subset = df1[(df1['Date'] >= start_date) & (df1['Date'] <= end_date)]
df2_subset = df2[(df2['Date'] >= start_date) & (df2['Date'] <= end_date)]

# Gerekli sütunları seç
df1_subset = df1_subset[['Date', 'Station', 'Unit', 'C/A']]
df2_subset = df2_subset[['Date', 'temperature_2m (°C)', 'precipitation (mm)', 'rain (mm)']]

# İki veri setini 'Date' sütununa göre birleştir
merged_df = pd.merge(df1_subset, df2_subset, on='Date', how='inner')

# Birleştirilmiş DataFrame'i ekrana yazdır
print(merged_df)
# Out:
# Empty DataFrame
# Columns: [Station, Unit, C/A, Date, temperature_2m (°C), precipitation (mm), rain (mm)]
# Index: []

# %%
print(df1_subset)
# Out:
# Empty DataFrame
# Columns: [Date, Station, Unit, C/A]
# Index: []

# %%
print(df2_subset)
# Out:
# Empty DataFrame
# Columns: [Date, temperature_2m (°C), precipitation (mm), rain (mm)]
# Index: []

# %%
# Tarih aralığını belirle
start_date = '2022-03-15'
end_date = '2022-06-01'

# %%
# Belirli tarih aralığındaki verileri seç
df1_subset = df1[(df1['Date'] >= start_date) & (df1['Date'] <= end_date)]
df2_subset = df2[(df2['Date'] >= start_date) & (df2['Date'] <= end_date)]

# %%
df1
# Out:
#             C/A  Unit       SCP        Station Line Name Division        Date  \
# 0          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# 1          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# 2          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# 3          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# 4          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# ...         ...   ...       ...            ...       ...      ...         ...
# 10963246  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
# 10963247  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
# 10963248  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
# 10963249  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
# 10963250  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
#
# ...

# %%
# Gerekli sütunları seç
df1_subset = df1_subset[['Date', 'Station', 'Unit', 'C/A']]
df2_subset = df2_subset[['Date', 'temperature_2m (°C)', 'precipitation (mm)', 'rain (mm)']]

# %%
# İki veri setini 'Date' sütununa göre birleştir
merged_df = pd.merge(df1_subset, df2_subset, on='Date', how='inner')

# %%
# Birleştirilmiş DataFrame'i ekrana yazdır
print(merged_df)
# Out:
# Empty DataFrame
# Columns: [Station, Unit, C/A, Date, temperature_2m (°C), precipitation (mm), rain (mm)]
# Index: []

# %%
df1_subset.merge(df2_subset, on='Date')
# Out:
# Empty DataFrame
# Columns: [Station, Unit, C/A, Date, temperature_2m (°C), precipitation (mm), rain (mm)]
# Index: []

# %%
df1_subset
# Out:
# Empty DataFrame
# Columns: [Date, Station, Unit, C/A]
# Index: []

# %%
df2_subset
# Out:
# Empty DataFrame
# Columns: [Date, temperature_2m (°C), precipitation (mm), rain (mm)]
# Index: []

# %%
df1
# Out:
#             C/A  Unit       SCP        Station Line Name Division        Date  \
# 0          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# 1          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# 2          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# 3          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# 4          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# ...         ...   ...       ...            ...       ...      ...         ...
# 10963246  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
# 10963247  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
# 10963248  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
# 10963249  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
# 10963250  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
#
# ...

# %%
df2
# Out:
#              Date  temperature_2m (°C)  precipitation (mm)  rain (mm)  \
# 0      01-01-2016                  7.6                 0.0        0.0
# 1      01-01-2016                  7.5                 0.0        0.0
# 2      01-01-2016                  7.1                 0.0        0.0
# 3      01-01-2016                  6.6                 0.0        0.0
# 4      01-01-2016                  6.3                 0.0        0.0
# ...           ...                  ...                 ...        ...
# 59582  19-10-2022                 12.2                 0.0        0.0
# 59583  19-10-2022                 12.2                 0.0        0.0
# 59584  19-10-2022                 12.2                 0.0        0.0
# 59585  19-10-2022                 11.1                 0.0        0.0
# 59586  19-10-2022                 10.4                 0.0        0.0
#
#        cloudcover (%)  cloudcover_low (%)  cloudcover_mid (%)  \
# 0                69.0                53.0                 0.0
# ...

# %%
# Tarih sütununu MM/DD/YYYY formatına çevir
df2['Date'] = pd.to_datetime(df2['Date'], format='%d-%m-%Y').dt.strftime('%m/%d/%Y')

# Sonucu yazdır
print(df2)
# Out:
#              Date  temperature_2m (°C)  precipitation (mm)  rain (mm)  \
# 0      01/01/2016                  7.6                 0.0        0.0
# 1      01/01/2016                  7.5                 0.0        0.0
# 2      01/01/2016                  7.1                 0.0        0.0
# 3      01/01/2016                  6.6                 0.0        0.0
# 4      01/01/2016                  6.3                 0.0        0.0
# ...           ...                  ...                 ...        ...
# 59582  10/19/2022                 12.2                 0.0        0.0
# 59583  10/19/2022                 12.2                 0.0        0.0
# 59584  10/19/2022                 12.2                 0.0        0.0
# 59585  10/19/2022                 11.1                 0.0        0.0
# 59586  10/19/2022                 10.4                 0.0        0.0
#
#        cloudcover (%)  cloudcover_low (%)  cloudcover_mid (%)  \
# 0                69.0                53.0                 0.0
# ...

# %%
from IPython.display import display

pd.options.display.max_columns = None
display(df2)
# Out:
#              Date  temperature_2m (°C)  precipitation (mm)  rain (mm)  \
# 0      01/01/2016                  7.6                 0.0        0.0
# 1      01/01/2016                  7.5                 0.0        0.0
# 2      01/01/2016                  7.1                 0.0        0.0
# 3      01/01/2016                  6.6                 0.0        0.0
# 4      01/01/2016                  6.3                 0.0        0.0
# ...           ...                  ...                 ...        ...
# 59582  10/19/2022                 12.2                 0.0        0.0
# 59583  10/19/2022                 12.2                 0.0        0.0
# 59584  10/19/2022                 12.2                 0.0        0.0
# 59585  10/19/2022                 11.1                 0.0        0.0
# 59586  10/19/2022                 10.4                 0.0        0.0
#
#        cloudcover (%)  cloudcover_low (%)  cloudcover_mid (%)  \
# 0                69.0                53.0                 0.0
# ...

# %%
df1
# Out:
#             C/A  Unit       SCP        Station Line Name Division        Date  \
# 0          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# 1          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# 2          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# 3          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# 4          A002  R051  02-00-00          59 ST   NQR456W      BMT  12/30/2022
# ...         ...   ...       ...            ...       ...      ...         ...
# 10963246  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
# 10963247  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
# 10963248  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
# 10963249  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
# 10963250  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT  01/01/2022
#
# ...

# %%
# Tarih aralığını belirle
start_date = '2022-15-03'
end_date = '2022-01-06'

# Belirli tarih aralığındaki verileri seç
df1_subset = df1[(df1['Date'] >= start_date) & (df1['Date'] <= end_date)]
df2_subset = df2[(df2['Date'] >= start_date) & (df2['Date'] <= end_date)]

# Gerekli sütunları seç
df1_subset = df1_subset[['Date', 'Station', 'Unit', 'C/A']]
df2_subset = df2_subset[['Date', 'temperature_2m (°C)', 'precipitation (mm)', 'rain (mm)']]

# İki veri setini 'Date' sütununa göre birleştir
merged_df = pd.merge(df1_subset, df2_subset, on='Date', how='inner')

# Birleştirilmiş DataFrame'i ekrana yazdır
print(merged_df)
# Out:
# Empty DataFrame
# Columns: [Station, Unit, C/A, Date, temperature_2m (°C), precipitation (mm), rain (mm)]
# Index: []

# %%
# Tarih sütunlarını datetime formatına çevir
df1['Date'] = pd.to_datetime(df1['Date'], format='%m/%d/%Y')
df2['Date'] = pd.to_datetime(df2['Date'], format='%m/%d/%Y')

# Belirli bir tarih aralığı belirleme
start_date = '03-15-2022'
end_date = '06-01-2022'

# Tarih aralığına göre filtreleme
filtered_df1 = df1[(df1['Date'] >= start_date) & (df1['Date'] <= end_date)]
filtered_df2 = df2[(df2['Date'] >= start_date) & (df2['Date'] <= end_date)]

# İki filtrelenmiş veri setini tarih sütunlarına göre birleştir
merged_df = pd.merge(filtered_df1, filtered_df2, on='Date')

# Sonucu yazdır
print(merged_df)
# Out:
#             C/A  Unit       SCP        Station Line Name Division       Date  \
# 0          A002  R051  02-00-00          59 ST   NQR456W      BMT 2022-06-01
# 1          A002  R051  02-00-00          59 ST   NQR456W      BMT 2022-06-01
# 2          A002  R051  02-00-00          59 ST   NQR456W      BMT 2022-06-01
# 3          A002  R051  02-00-00          59 ST   NQR456W      BMT 2022-06-01
# 4          A002  R051  02-00-00          59 ST   NQR456W      BMT 2022-06-01
# ...         ...   ...       ...            ...       ...      ...        ...
# 54252961  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT 2022-03-15
# 54252962  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT 2022-03-15
# 54252963  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT 2022-03-15
# 54252964  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT 2022-03-15
# 54252965  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT 2022-03-15
#
#               Time Description  Entries  \
# ...

# %%
from IPython.display import display

pd.options.display.max_columns = None
display(merged_df)
# Out:
#             C/A  Unit       SCP        Station Line Name Division       Date  \
# 0          A002  R051  02-00-00          59 ST   NQR456W      BMT 2022-06-01
# 1          A002  R051  02-00-00          59 ST   NQR456W      BMT 2022-06-01
# 2          A002  R051  02-00-00          59 ST   NQR456W      BMT 2022-06-01
# 3          A002  R051  02-00-00          59 ST   NQR456W      BMT 2022-06-01
# 4          A002  R051  02-00-00          59 ST   NQR456W      BMT 2022-06-01
# ...         ...   ...       ...            ...       ...      ...        ...
# 54252961  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT 2022-03-15
# 54252962  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT 2022-03-15
# 54252963  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT 2022-03-15
# 54252964  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT 2022-03-15
# 54252965  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT 2022-03-15
#
#               Time Description  Entries  \
# ...

# %%
print(merged_df.head(25))
# Out:
#      C/A  Unit       SCP Station Line Name Division       Date      Time  \
# 0   A002  R051  02-00-00   59 ST   NQR456W      BMT 2022-06-01  00:00:00
# 1   A002  R051  02-00-00   59 ST   NQR456W      BMT 2022-06-01  00:00:00
# 2   A002  R051  02-00-00   59 ST   NQR456W      BMT 2022-06-01  00:00:00
# 3   A002  R051  02-00-00   59 ST   NQR456W      BMT 2022-06-01  00:00:00
# 4   A002  R051  02-00-00   59 ST   NQR456W      BMT 2022-06-01  00:00:00
# 5   A002  R051  02-00-00   59 ST   NQR456W      BMT 2022-06-01  00:00:00
# 6   A002  R051  02-00-00   59 ST   NQR456W      BMT 2022-06-01  00:00:00
# 7   A002  R051  02-00-00   59 ST   NQR456W      BMT 2022-06-01  00:00:00
# 8   A002  R051  02-00-00   59 ST   NQR456W      BMT 2022-06-01  00:00:00
# 9   A002  R051  02-00-00   59 ST   NQR456W      BMT 2022-06-01  00:00:00
# 10  A002  R051  02-00-00   59 ST   NQR456W      BMT 2022-06-01  00:00:00
# 11  A002  R051  02-00-00   59 ST   NQR456W      BMT 2022-06-01  00:00:00
# ...

# %%
merged_df.info
# Out:
# <bound method DataFrame.info of             C/A  Unit       SCP        Station Line Name Division       Date  \
# 0          A002  R051  02-00-00          59 ST   NQR456W      BMT 2022-06-01
# 1          A002  R051  02-00-00          59 ST   NQR456W      BMT 2022-06-01
# 2          A002  R051  02-00-00          59 ST   NQR456W      BMT 2022-06-01
# 3          A002  R051  02-00-00          59 ST   NQR456W      BMT 2022-06-01
# 4          A002  R051  02-00-00          59 ST   NQR456W      BMT 2022-06-01
# ...         ...   ...       ...            ...       ...      ...        ...
# 54252961  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT 2022-03-15
# 54252962  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT 2022-03-15
# 54252963  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT 2022-03-15
# 54252964  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT 2022-03-15
# 54252965  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT 2022-03-15
#
# ...

# %%
merged_df.isnull().sum()
# Out:
# C/A                                                           0
# Unit                                                          0
# SCP                                                           0
# Station                                                       0
# Line Name                                                     0
# Division                                                      0
# Date                                                          0
# Time                                                          0
# Description                                                   0
# Entries                                                       0
# Exits                                                         0
# temperature_2m (°C)                                           0
# precipitation (mm)                                            0
# rain (mm)                                                     0
# cloudcover (%)                                                0
# ...

# %%
merged_df.Station.value_counts() #kaç tane olduğunu gösterir.
# Out:
# 34 ST-PENN STA     1096410
# GRD CNTRL-42 ST    1039332
# FULTON ST          1034650
# 23 ST               795813
# 86 ST               700200
#                     ...
# BROAD CHANNEL        32022
# CHAUNCEY ST          31446
# CLEVELAND ST         21588
# SUTTER AV            21564
# ORCHARD BEACH         7872
# Name: Station, Length: 379, dtype: int64

# %%
merged_df.drop_duplicates(inplace=True) #tekrar eden değerleri siler.

# %%
merged_df.duplicated().sum()
# Out:
# 0

# %%
top_stations = merged_df['Station'].value_counts().head(5)
print(top_stations)
# Out:
# 34 ST-PENN STA     1096410
# GRD CNTRL-42 ST    1039332
# FULTON ST          1034650
# 23 ST               795813
# 86 ST               700200
# Name: Station, dtype: int64

# %%
# 'Station' sütunundaki en çok tekrar eden 5 istasyonu bul
top_stations = merged_df['Station'].value_counts().head(5)

# Yüzdelik dilimleri hesapla
percentage_distribution = top_stations / top_stations.sum() * 100

# Pasta grafiğini çiz
plt.figure(figsize=(10, 6))
plt.pie(percentage_distribution, labels=percentage_distribution.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette(palette=["#b298dc", "#F0A6CA", "#EFC3E6", "#F0D9FF", "#f7aef8", "#c8e7ff"]))
plt.title('Top 5 Stations - Percentage Distribution')
plt.show()

# Sayıların çubuk grafiğini çiz
plt.figure(figsize=(10, 6))
sns.barplot(x=top_stations.index, y=top_stations, palette=["#b298dc", "#F0A6CA", "#EFC3E6", "#F0D9FF", "#f7aef8", "#c8e7ff"])
plt.title('Top 5 Stations - Count Distribution')
plt.xlabel('Station')
plt.ylabel('Toplam Giriş Sayısı')
plt.show()

# %%
# precipitation ve rain değerleri sıfır olan ve temperature_2m değeri 20 veya daha büyük olan durumları seç
filtrelenmis_durumlar = merged_df[(merged_df['precipitation (mm)'] == 0) & (merged_df['rain (mm)'] == 0) & (merged_df['temperature_2m (°C)'] >= 20)]
print(filtrelenmis_durumlar)
# Out:
#             C/A  Unit       SCP        Station Line Name Division       Date  \
# 724248     A002  R051  02-00-00          59 ST   NQR456W      BMT 2022-05-31
# 724249     A002  R051  02-00-00          59 ST   NQR456W      BMT 2022-05-31
# 724250     A002  R051  02-00-00          59 ST   NQR456W      BMT 2022-05-31
# 724251     A002  R051  02-00-00          59 ST   NQR456W      BMT 2022-05-31
# 724252     A002  R051  02-00-00          59 ST   NQR456W      BMT 2022-05-31
# ...         ...   ...       ...            ...       ...      ...        ...
# 38352241  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT 2022-04-06
# 38352242  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT 2022-04-06
# 38352243  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT 2022-04-06
# 38352244  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT 2022-04-06
# 38352245  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT 2022-04-06
#
#               Time Description  Entries  \
# ...

# %%
from IPython.display import display

pd.options.display.max_columns = None
display(filtrelenmis_durumlar)
# Out:
#             C/A  Unit       SCP        Station Line Name Division       Date  \
# 724248     A002  R051  02-00-00          59 ST   NQR456W      BMT 2022-05-31
# 724249     A002  R051  02-00-00          59 ST   NQR456W      BMT 2022-05-31
# 724250     A002  R051  02-00-00          59 ST   NQR456W      BMT 2022-05-31
# 724251     A002  R051  02-00-00          59 ST   NQR456W      BMT 2022-05-31
# 724252     A002  R051  02-00-00          59 ST   NQR456W      BMT 2022-05-31
# ...         ...   ...       ...            ...       ...      ...        ...
# 38352241  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT 2022-04-06
# 38352242  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT 2022-04-06
# 38352243  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT 2022-04-06
# 38352244  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT 2022-04-06
# 38352245  TRAM2  R469  00-05-01  RIT-ROOSEVELT         R      RIT 2022-04-06
#
#               Time Description  Entries  \
# ...

# %%
# 'Station' sütunundaki en çok tekrar eden 5 istasyonu bul
top_stations = filtrelenmis_durumlar['Station'].value_counts().head(5)

# Yüzdelik dilimleri hesapla
percentage_distribution = top_stations / top_stations.sum() * 100

# Pasta grafiğini çiz
plt.figure(figsize=(10, 6))
plt.pie(percentage_distribution, labels=percentage_distribution.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette(palette=["#b298dc", "#F0A6CA", "#EFC3E6", "#F0D9FF", "#f7aef8", "#c8e7ff"]))
plt.title('Top 5 Stations - Percentage Distribution')
plt.show()

# Sayıların çubuk grafiğini çiz
plt.figure(figsize=(10, 6))
sns.barplot(x=top_stations.index, y=top_stations, palette=["#b298dc", "#F0A6CA", "#EFC3E6", "#F0D9FF", "#f7aef8", "#c8e7ff"])
plt.title('Top 5 Stations - Count Distribution')
plt.xlabel('Station')
plt.ylabel('Toplam Giriş Sayısı')
plt.show()
